# %%
import pandas as pd

# %%
#well= pd.read_csv('https://raw.githubusercontent.com/edisonc57/ML_Oil-and-gas/main/Data/well_18_ml_v1.csv',usecols=[0,5,7,17])
well= pd.read_csv('https://raw.githubusercontent.com/edisonc57/ML_Oil-and-gas/main/Data/well_18_ml_v1.csv')

# %%
well.head()
# Out:
#   wellName    DEPTH       CGR   CPERM       CPHI        DT      DTSM  Facies  \
# 0  A-18-00  852.857   4.91913 -9999.0 -9999.0000   74.5270  121.9698       1
# 1  A-18-00  853.010   9.99433 -9999.0 -9999.0000   88.8155  141.6838       1
# 2  A-18-00  853.162  20.56400 -9999.0 -9999.0000   99.0574  166.7016       5
# 3  A-18-00  853.314  31.71550 -9999.0 -9999.0000  104.7870  182.5868       5
# 4  A-18-00  853.467  37.70880 -9999.0     0.4288  104.8980  185.0199       5
#
#         GR     MSFL      NPHI       PEF  Perm_Buckles_UpAs      PHIE     RHOB  \
# 0  33.3418  5.79568  0.079834  4.783249           0.931011  0.072167  2.74411
# 1  53.4034  2.36973  0.151655  4.399977           9.209792  0.146527  2.61065
# 2  72.0957  1.31614  0.231567  4.030700           1.601786  0.220162  2.47339
# 3  78.3783  1.20371  0.287493  3.732858           3.690761  0.276589  2.35818
# 4  70.4172  1.42773  0.297283  3.520631           5.106259  0.301175  2.29512
#
# ...

# %%
print(well.columns.values)
# Out:
# ['wellName' 'DEPTH' 'CGR' 'CPERM' 'CPHI' 'DT' 'DTSM' 'Facies' 'GR' 'MSFL'
#  'NPHI' 'PEF' 'Perm_Buckles_UpAs' 'PHIE' 'RHOB' 'RT' 'SWE' 'ZONE_NAME'
#  'net_gross']

# %%
print(well.dtypes)
# Out:
# wellName              object
# DEPTH                float64
# CGR                  float64
# CPERM                float64
# CPHI                 float64
# DT                   float64
# DTSM                 float64
# Facies                 int64
# GR                   float64
# MSFL                 float64
# NPHI                 float64
# PEF                  float64
# Perm_Buckles_UpAs    float64
# PHIE                 float64
# RHOB                 float64
# RT                   float64
# SWE                  float64
# ZONE_NAME             object
# net_gross             object
# dtype: object

# %% [markdown]
# Haga doble clic <b>aquí</b> para ver la solución.
#
# <!-- Respuesta:
#
# df_column=df[['NombreColumna']]
# df_column.dtypes
#
# -->

# %% [markdown]
# ## <strong>Visualizar las estadísticas</strong>

# %%
well.shape
# Out:
# (1104, 19)

# %%
well.describe()
# Out:
#              DEPTH          CGR         CPERM         CPHI           DT  \
# count  1104.000000  1104.000000   1104.000000  1104.000000  1104.000000
# mean    936.905800    22.047920  -9209.272460 -7816.181810  -116.954717
# std      48.591466    14.814058   3000.540084  4132.484386  1474.010579
# min     852.857000    -1.820080  -9999.000000 -9999.000000 -9999.000000
# 25%     894.881750    10.967600  -9999.000000 -9999.000000    80.797725
# 50%     936.906000    19.478800  -9999.000000 -9999.000000    95.242200
# 75%     978.930000    30.318275  -9999.000000 -9999.000000   119.451500
# max    1020.950000    77.795400  24967.240230     0.431600   177.691000
#
#               DTSM       Facies           GR         MSFL         NPHI  \
# count  1104.000000  1104.000000  1104.000000  1104.000000  1104.000000
# mean    228.850209 -3502.405797    33.949555     1.031004     0.285081
# std      79.061065  4775.055663    13.704293     1.875299     0.055071
# ...

# %%
well.describe(include=['object'])
# Out:
#        wellName ZONE_NAME net_gross
# count      1104      1104      1104
# unique        1         5         2
# top     A-18-00      Ghar       net
# freq       1104       580       794

# %%
well.describe(include="all")
# Out:
#        wellName        DEPTH          CGR         CPERM         CPHI  \
# count      1104  1104.000000  1104.000000   1104.000000  1104.000000
# unique        1          NaN          NaN           NaN          NaN
# top     A-18-00          NaN          NaN           NaN          NaN
# freq       1104          NaN          NaN           NaN          NaN
# mean        NaN   936.905800    22.047920  -9209.272460 -7816.181810
# std         NaN    48.591466    14.814058   3000.540084  4132.484386
# min         NaN   852.857000    -1.820080  -9999.000000 -9999.000000
# 25%         NaN   894.881750    10.967600  -9999.000000 -9999.000000
# 50%         NaN   936.906000    19.478800  -9999.000000 -9999.000000
# 75%         NaN   978.930000    30.318275  -9999.000000 -9999.000000
# max         NaN  1020.950000    77.795400  24967.240230     0.431600
#
#                  DT         DTSM       Facies           GR         MSFL  \
# ...

# %%
Zone = well['ZONE_NAME'].value_counts().to_frame()
print(Zone)
# Out:
#            count
# ZONE_NAME
# Ghar         580
# Dammam       245
# U.Asmari     137
# L.Asmari     119
# Ghar C.R      23
